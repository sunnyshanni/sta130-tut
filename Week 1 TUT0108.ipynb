# %%
import pandas as pd

# URL of the Titanic dataset
url = 'https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv'

# Load the dataset into a DataFrame
df = pd.read_csv(url)

# Display the first few rows of the DataFrame
print("First few rows of the dataset:")
print(df.head())

# Get the missing data counts for each column
missing_data_counts = df.isnull().sum()

# Display the missing data counts
print("\nMissing data counts for each column:")
print(missing_data_counts)
# Out:
# First few rows of the dataset:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500
#
# Missing data counts for each column:
# ...

# %% [markdown]
# Certainly! Here’s a summary of our interaction:
#
# ---
#
# **Summary of Interaction:**
#
# **Objective:**
# The goal was to find an interesting dataset with missing values available online and to obtain the missing data counts for this dataset using Pandas.
#
# **Dataset Selected:**
# The Titanic dataset from Stanford University was chosen for its relevance and educational value. The dataset contains information about passengers on the Titanic and includes several columns with missing values.
#
# **Dataset URL:**
# The dataset can be accessed at [Titanic Dataset](https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv).
#
# **Pandas Code Provided:**
# To download and load the dataset into a Pandas DataFrame:
# ```python
# import pandas as pd
#
# # URL of the Titanic dataset
# url = 'https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv'
#
# # Load the dataset into a DataFrame
# df = pd.read_csv(url)
#
# # Display the first few rows of the DataFrame
# print(df.head())
# ```
#
# To get the counts of missing data for each column:
# ```python
# import pandas as pd
#
# # URL of the Titanic dataset
# url = 'https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv'
#
# # Load the dataset into a DataFrame
# df = pd.read_csv(url)
#
# # Get the missing data counts for each column
# missing_data_counts = df.isnull().sum()
#
# # Display the missing data counts
# print(missing_data_counts)
# ```
#
# **Outcome:**
# The provided code will help in loading the Titanic dataset and analyzing missing data by providing a count of missing values for each column.
#
# ---
#
# Feel free to adjust or expand upon this summary as needed!
